# %% [markdown]
# ### Imports

# %%
from uatk_spc import Builder

path = "../../data/output/England/2020"
region = "rutland"

# %% [markdown]
# #### Example with `Builder` class combining people and households

# %%
df = (
    Builder(path, region, backend="pandas", input_type="protobuf")
    .add_households()
    .unnest(["health", "details"])
    .build()
)

# %%
df.columns
# Out:
# Index(['id', 'household', 'workplace', 'demographics', 'employment', 'events',
#        'weekday_diaries', 'weekend_diaries', 'orig_pid', 'id_tus_hh',
#        'id_tus_p', 'pid_hs', 'msoa11cd', 'oa11cd', 'members', 'bmi',
#        'has_cardiovascular_disease', 'has_diabetes', 'has_high_blood_pressure',
#        'self_assessed_health', 'life_satisfaction', 'number_medications',
#        'hid', 'nssec8', 'accommodation_type', 'num_rooms', 'central_heat',
#        'tenure', 'num_cars', 'communal_type'],
#       dtype='object')

# %%
df.head()
# Out:
#   id household workplace                                       demographics  \
# 0  0         0      1168  {'sex': 'MALE', 'age_years': 44, 'ethnicity': ...
# 1  1         0       155  {'sex': 'FEMALE', 'age_years': 41, 'ethnicity'...
# 2  2         1         0  {'sex': 'MALE', 'age_years': 68, 'ethnicity': ...
# 3  3         1         0  {'sex': 'FEMALE', 'age_years': 62, 'ethnicity'...
# 4  4         1         0  {'sex': 'MALE', 'age_years': 10, 'ethnicity': ...
#
#                                           employment  \
# 0  {'sic1d2007': 'F', 'sic2d2007': '43', 'soc2010...
# 1  {'sic1d2007': 'G', 'sic2d2007': '47', 'soc2010...
# 2  {'sic1d2007': 'S', 'sic2d2007': '96', 'soc2010...
# 3  {'sic1d2007': 'P', 'sic2d2007': '85', 'soc2010...
# 4  {'pwkstat': 'NA', 'sic1d2007': '', 'sic2d2007'...
#
#                                               events  \
# 0  {'sport': 0.255, 'rugby': 0.16065, 'concert_m'...
# 1  {'sport': 0.255, 'rugby': 0.1887, 'concert_m':...
# 2  {'sport': 0.239, 'rugby': 0.15057, 'concert_m'...
# 3  {'sport': 0.268, 'rugby': 0.09916, 'concert_m'...
# 4  {'sport': 0.257, 'rugby': 0.16191, 'concert_m'...
#
#                                      weekday_diaries  \
# 0  [1796, 2877, 4451, 5231, 5497, 6073, 6593, 669...
# 1  [289, 2183, 2190, 6542, 7132, 9122, 9730, 1035...
# 2  [89, 677, 1331, 1480, 2111, 3457, 4855, 5763, ...
# 3           [2844, 5035, 11790, 12206, 12444, 15284]
# 4  [33, 74, 213, 264, 291, 533, 548, 549, 561, 56...
#
#                                      weekend_diaries            orig_pid  \
# 0  [1795, 2876, 4452, 5230, 5496, 6072, 6592, 669...  E02002863_0001_001
# 1  [288, 2184, 2189, 6543, 7133, 9123, 9729, 1035...  E02002863_0001_002
# 2  [88, 678, 1330, 1481, 2110, 3458, 4854, 5762, ...  E02002863_0002_001
# 3           [2845, 5034, 11791, 12207, 12443, 15283]  E02002863_0002_002
# 4  [32, 75, 212, 265, 290, 534, 547, 550, 562, 56...  E02002863_0002_003
#
#   id_tus_hh  ... life_satisfaction number_medications             hid  \
# 0  17310308  ...              HIGH                  0  E02002863_0001
# 1  12050117  ...         VERY_HIGH                  1  E02002863_0001
# 2  11280408  ...               LOW                  0  E02002863_0002
# 3  16110805  ...            MEDIUM                  0  E02002863_0002
# 4  16241112  ...               LOW                  0  E02002863_0002
#
#         nssec8 accommodation_type  num_rooms  central_heat          tenure  \
# 0  SEMIROUTINE           DETACHED          6          True     OWNED_FULLY
# 1  SEMIROUTINE           DETACHED          6          True     OWNED_FULLY
# 2        SUPER           TERRACED          5          True  RENTED_PRIVATE
# 3        SUPER           TERRACED          5          True  RENTED_PRIVATE
# 4        SUPER           TERRACED          5          True  RENTED_PRIVATE
#
#    num_cars communal_type
# 0         1      COMMUNAL
# 1         1      COMMUNAL
# 2         2      COMMUNAL
# 3         2      COMMUNAL
# 4         2      COMMUNAL
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Example with `Builder` class combining people and time use diaries

# %%
# Subset of features to include and unnest
features = {
    "health": [
        "bmi",
        "has_cardiovascular_disease",
        "has_diabetes",
        "has_high_blood_pressure",
        "self_assessed_health",
        "life_satisfaction",
    ],
    "demographics": ["age_years", "sex", "nssec8"],
    "employment": ["pwkstat", "salary_yearly"],
    
}

df = (
    Builder(path, region, backend="pandas", input_type="protobuf")
    .add_time_use_diaries(features, diary_type="weekday_diaries")
    .build()
)

# %%
df.columns
# Out:
# Index(['id', 'household', 'bmi', 'has_cardiovascular_disease', 'has_diabetes',
#        'has_high_blood_pressure', 'self_assessed_health', 'life_satisfaction',
#        'age_years', 'sex', 'nssec8', 'pwkstat', 'salary_yearly',
#        'weekday_diaries', 'uid', 'weekday', 'day_type', 'month', 'pworkhome',
#        'phomeother', 'pwork', 'pschool', 'pshop', 'pservices', 'pleisure',
#        'pescort', 'ptransport', 'phome_total', 'pnothome_total',
#        'punknown_total', 'pmwalk', 'pmcycle', 'pmprivate', 'pmpublic',
#        'pmunknown', 'age35g'],
#       dtype='object')

# %%
df.head()
# Out:
#   id household       bmi  has_cardiovascular_disease  has_diabetes  \
# 0  0         0  39.47709                       False         False
# 1  0         0  39.47709                       False         False
# 2  0         0  39.47709                       False         False
# 3  0         0  39.47709                       False         False
# 4  0         0  39.47709                       False         False
#
#    has_high_blood_pressure self_assessed_health life_satisfaction  age_years  \
# 0                    False                 GOOD              HIGH         44
# 1                    False                 GOOD              HIGH         44
# 2                    False                 GOOD              HIGH         44
# 3                    False                 GOOD              HIGH         44
# 4                    False                 GOOD              HIGH         44
#
#     sex  ... ptransport phome_total  pnothome_total punknown_total   pmwalk  \
# 0  MALE  ...    0.12500     0.81945         0.18055            0.0  0.00000
# 1  MALE  ...    0.15278     0.36133         0.63867            0.0  0.00000
# 2  MALE  ...    0.27778     0.31944         0.68056            0.0  0.00000
# 3  MALE  ...    0.15278     0.47222         0.52778            0.0  0.00000
# 4  MALE  ...    0.18750     0.68056         0.31944            0.0  0.11111
#
#    pmcycle  pmprivate  pmpublic  pmunknown  age35g
# 0  0.00000    0.92857       0.0    0.07143      12
# 1  0.00000    0.95455       0.0    0.04545      12
# 2  0.00000    1.00000       0.0    0.00000      12
# 3  0.00000    1.00000       0.0    0.00000      12
# 4  0.59259    0.96296       0.0    0.03704      12
#
# [5 rows x 36 columns]
